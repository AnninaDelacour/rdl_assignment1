# %%
# Uncomment and run this cell if you're on Colab or Kaggle
# !git clone https://github.com/nlp-with-transformers/notebooks.git
# %cd notebooks
from install import *
install_requirements()
# Out:
# Cloning into 'notebooks'...
# remote: Enumerating objects: 530, done.
# remote: Counting objects: 100% (210/210), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 530 (delta 183), reused 159 (delta 159), pack-reused 320 (from 2)
# Receiving objects: 100% (530/530), 30.79 MiB | 23.63 MiB/s, done.
# Resolving deltas: 100% (252/252), done.
# /content/notebooks/notebooks
# ⏳ Installing base requirements ...
# ✅ Base requirements installed!
# ⏳ Installing Git LFS ...
# ✅ Git LFS installed!

# %%
#hide_output
from transformers import pipeline

# %%
text = """Instead of performing a single attention function with dmodel-dimensional keys, values and queries,
we found it beneficial to linearly project the queries, keys and values h times with different, learned
linear projections to dk, dk and dv dimensions, respectively. On each of these projected versions of
queries, keys and values we then perform the attention function in parallel, yielding dv-dimensional output values. These are concatenated and once again projected, resulting in the final values, as
depicted in Figure 2.
Multi-head attention allows the model to jointly attend to information from different representation
subspaces at different positions. With a single attention head, averaging inhibits this.
In this work we employ h = 8 parallel attention layers, or heads. For each of these we use
dk = dv = dmodel/h = 64. Due to the reduced dimension of each head, the total computational cost
is similar to that of single-head attention with full dimensionality.
We call our particular attention "Scaled Dot-Product Attention" (Figure 2). The input consists of
queries and keys of dimension dk, and values of dimension dv. We compute the dot products of the
query with all keys, divide each by √
dk, and apply a softmax function to obtain the weights on the
values.
In practice, we compute the attention function on a set of queries simultaneously, packed together
into a matrix Q. The keys and values are also packed together into matrices K and V . We compute
the matrix of outputs as:
The two most commonly used attention functions are additive attention , and dot-product (multiplicative) attention. Dot-product attention is identical to our algorithm, except for the scaling factor
of √
1
dk
. Additive attention computes the compatibility function using a feed-forward network with
a single hidden layer. While the two are similar in theoretical complexity, dot-product attention is
much faster and more space-efficient in practice, since it can be implemented using highly optimized
matrix multiplication code.
While for small values of dk the two mechanisms perform similarly, additive attention outperforms
dot product attention without scaling for larger values of dk . We suspect that for large values of
dk, the dot products grow large in magnitude, pushing the softmax function into regions where it has
extremely small gradients."""

# %%
#hide_output
from transformers import pipeline

classifier = pipeline("text-classification")
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english)
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
import pandas as pd

outputs = classifier(text)
pd.DataFrame(outputs)
# Out:
#       label     score
# 0  NEGATIVE  0.996086

# %% [markdown]
# ## Model = default

# %%
from pickle import TRUE
reader = pipeline("question-answering")
#question = "Is it worth watching the series?"
question = "What is the text about?"
outputs = reader(question=question, context=text, padding = "longest")
pd.DataFrame([outputs])
# Out:
# No model was supplied, defaulted to distilbert-base-cased-distilled-squad (https://huggingface.co/distilbert-base-cased-distilled-squad)
#       score  start   end                        answer
# 0  0.010154   1008  1036  Scaled Dot-Product Attention

# %%
from pickle import TRUE
reader = pipeline("question-answering")
#question = "Is it worth watching the series?"
question = "What is the primary advantage of multi-head attention over a single attention head?"
outputs = reader(question=question, context=text, padding = "longest")
pd.DataFrame([outputs])
# Out:
# No model was supplied, defaulted to distilbert-base-cased-distilled-squad (https://huggingface.co/distilbert-base-cased-distilled-squad)
#       score  start  end                                             answer
# 0  0.137557    567  659  jointly attend to information from different r...

# %%
from pickle import TRUE
reader = pipeline("question-answering")
#question = "Is it worth watching the series?"
question = "How does dot-product attention compare to additive attention in terms of efficiency?"
outputs = reader(question=question, context=text, padding = "longest")
pd.DataFrame([outputs])
# Out:
# No model was supplied, defaulted to distilbert-base-cased-distilled-squad (https://huggingface.co/distilbert-base-cased-distilled-squad)
#       score  start   end          answer
# 0  0.635691   1588  1602  multiplicative

# %%
from pickle import TRUE
reader = pipeline("question-answering")
#question = "Is it worth watching the series?"
question = "What dimensionality has the inner-layer?"
outputs = reader(question=question, context=text, padding = "longest")
pd.DataFrame([outputs])
# Out:
# No model was supplied, defaulted to distilbert-base-cased-distilled-squad (https://huggingface.co/distilbert-base-cased-distilled-squad)
#       score  start  end          answer
# 0  0.205867    739  753  h = 8 parallel

# %% [markdown]
# Model =

# %%
from pickle import TRUE
reader = pipeline("question-answering", model = "bert-large-uncased-whole-word-masking-finetuned-squad")
#question = "Is it worth watching the series?"
question = "What is the text about?"
outputs = reader(question=question, context=text, padding = "longest")
pd.DataFrame([outputs])
# Out:
#       score  start  end    answer
# 0  0.000471    516  524  Figure 2

# %%
from pickle import TRUE
reader = pipeline("question-answering", model = "bert-large-uncased-whole-word-masking-finetuned-squad")
#question = "Is it worth watching the series?"
question = "What is the primary advantage of multi-head attention over a single attention head?"
outputs = reader(question=question, context=text, padding = "longest")
pd.DataFrame([outputs])
# Out:
#       score  start  end                                             answer
# 0  0.038387    567  659  jointly attend to information from different r...

# %%
from pickle import TRUE
reader = pipeline("question-answering", model = "bert-large-uncased-whole-word-masking-finetuned-squad")
#question = "Is it worth watching the series?"
question = "How does dot-product attention compare to additive attention in terms of efficiency?"
outputs = reader(question=question, context=text, padding = "longest")
pd.DataFrame([outputs])
# Out:
#       score  start   end                      answer
# 0  0.371858   1640  1666  identical to our algorithm

# %%
from pickle import TRUE
reader = pipeline("question-answering", model = "bert-large-uncased-whole-word-masking-finetuned-squad")
#question = "Is it worth watching the series?"
question = "What dimensionality has the inner-layer?"
outputs = reader(question=question, context=text, padding = "longest")
pd.DataFrame([outputs])
# Out:
#       score  start  end answer
# 0  0.160717    237  239     dv

# %% [markdown]
# ## Modell =  deepset/roberta-base-squad2

# %%
from pickle import TRUE
reader = pipeline("question-answering", model = "deepset/roberta-base-squad2")
#question = "Is it worth watching the series?"
question = "What is the text about?"
outputs = reader(question=question, context=text, padding = "longest")
pd.DataFrame([outputs])
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#      score  start   end answer
# 0  0.00124   1206  1209   \ndk

# %%
from pickle import TRUE
reader = pipeline("question-answering", model = "deepset/roberta-base-squad2")
#question = "Is it worth watching the series?"
question = "What is the primary advantage of multi-head attention over a single attention head?"
outputs = reader(question=question, context=text, padding = "longest")
pd.DataFrame([outputs])
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#       score  start  end                   answer
# 0  0.086338    691  714  averaging inhibits this

# %%
from pickle import TRUE
reader = pipeline("question-answering", model = "deepset/roberta-base-squad2")
#question = "Is it worth watching the series?"
question = "How does dot-product attention compare to additive attention in terms of efficiency?"
outputs = reader(question=question, context=text, padding = "longest")
pd.DataFrame([outputs])
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#       score  start   end                                answer
# 0  0.121765   1900  1936  much faster and more space-efficient

# %%
from pickle import TRUE
reader = pipeline("question-answering", model = "deepset/roberta-base-squad2")
#question = "Is it worth watching the series?"
question = "What dimensionality has the inner-layer?"
outputs = reader(question=question, context=text, padding = "longest")
pd.DataFrame([outputs])
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#       score  start   end answer
# 0  0.000209   1205  1209  √\ndk
